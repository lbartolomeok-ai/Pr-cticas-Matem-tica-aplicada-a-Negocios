# %% [markdown]
# # <font color="#07a8ed">**Ejercitación**

# %% [markdown]
# ## <font color="#07a8ed">**Ejercicio 01**

# %% [markdown]
# **Ejercicio 01**. Dadas las siguientes proposiciones:
# - $P$: "El número es par"
# - $Q$: "El número es mayor que 10"
#
# Pida un número entero al usuario.
#
# Evalue y muestre el resultado de las siguientes proposiciones lógicas:
#
# 1. $P \wedge Q$ (El número es par y mayor que 10).
#
# 2. $P \lor Q$ (El número es par o mayor que 10).
# 3. $\lnot Q$ (El número no es mayor que 10).

# %%
numero = int(input("Ingresá un número entero: "))

P = (numero % 2 == 0)
Q = (numero > 10)

conjuncion = # Su código acá...
disyuncion = # Su código acá...
negacion_Q = # Su código acá...

print(f"Punto 1: P ∧ Q → {conjuncion}")
print(f"Punto 2: P ∨ Q → {disyuncion}")
print(f"Punto 3: ¬Q → {negacion_Q}")
# Out:
#   File "/tmp/ipython-input-2427456653.py", line 6
#     conjuncion = # Su código acá...
#                  ^
# SyntaxError: invalid syntax

# %% [markdown]
# Doble-click __aquí__ para la solución propuesta.
# <!-- The correct answer is:
#
# numero = int(input("Ingresá un número entero: "))
#
# P = (numero % 2 == 0)
# Q = (numero > 10)
#
# conjuncion = P and Q
# disyuncion = P or Q
# negacion_Q = not Q
#
# print(f"Punto 1: p ∧ q → {conjuncion}")
# print(f"Punto 2: p ∨ q → {disyuncion}")
# print(f"Punto 3: ¬q → {negacion_q}")
#
# -->

# %% [markdown]
# ## <font color="#07a8ed">**Ejercicio 02**

# %% [markdown]
# **Ejercicio 02**. Dados siguientes datos:
# - $a$ = 10
# - $b$ = 7
# - Una variable booleana $flag$ = `False`
#
# Considere la proposición lógica:
#
# $$
# \big( (a \times b > 60) \;\wedge\; (a - b < 5) \big) \;\vee\; flag
# $$
#
# 1. Calcule $a \times b$ y verifique si se cumple la proposición $(a \times b > 60)$.
# 2. Calcule $(a - b)$ y verifique si se cumple la proposición $(a - b < 5)$.
# 3. Evalue la conjunción $((a \times b > 60) \wedge (a - b < 5))$.
# 4. Considerando que $flag$ = `False`, evalue la disyunción completa.

# %%
# Su código aquí...

# %% [markdown]
# Doble-click __aquí__ para la solución propuesta.
# <!-- The correct answer is:
# # Datos
# a = 10
# b = 7
# flag = False
#
# # Punto 1: calcular a * b y verificar si a * b > 60
# producto = a * b
# cond1 = producto > 60
# print(f"Punto 1: a * b = {producto}, a * b > 60? {cond1}")
#
# # Punto 2: calcular a - b y verificar si a - b < 5
# resta = a - b
# cond2 = resta < 5
# print(f"Punto 2: a - b = {resta}, a - b < 5? {cond2}")
#
# # Punto 3: evaluar la conjunción (a * b > 60) ∧ (a - b < 5)
# conjuncion = cond1 and cond2
# print(f"Punto 3: (a * b > 60) ∧ (a - b < 5) = {conjuncion}")
#
# # Punto 4: evaluar la disyunción con flag y resultado final
# resultado_final = conjuncion or flag
# print(f"Punto 4: ((a * b > 60) ∧ (a - b < 5)) ∨ flag = {resultado_final}")
# -->

# %% [markdown]
# ```
# # Esto tiene formato de código
# ```
#
# ## <font color="#07a8ed">**Ejercicio 03**

# %% [markdown]
# Dado los conjunto:
#
# * $A$ = {1, 2, 3, 4}
# * $B$ = {3, 4, 5, 6}
#
# Calcule:
#
# 1. La unión de ellos.
# 2. La intersección.
# 3. La diferencia de $A$ con $B$.
# 4. La diferencia simétrica de $B$ con $A$ y compare el resultado con la diferencia simétrica de $A$ con $B$.

# %%
# Su código aquí...

# %% [markdown]
# Doble-click __aquí__ para la solución propuesta.
# <!-- The correct answer is:
#
# A = {1, 2, 3, 4}
# B = {3, 4, 5, 6}
#
# union = A | B
# interseccion = A & B
# diferencia = A - B
# diff_sim_A_B = A ^ B
# diff_sim_B_A = B ^ A
#
# print("Unión:", union)
# print("Intersección:", interseccion)
# print("Diferencia A - B:", diferencia)
# print("Diferencia simétrica A ^ B:", diff_sim_A_B)
# print("Diferencia simétrica B ^ A:", diff_sim_B_A)
# print("¿Diferencias simétricas iguales?", diff_sim_A_B == diff_sim_B_A)
#
# -->

# %% [markdown]
# ## <font color="#07a8ed">**Ejercicio 04**

# %% [markdown]
# Defina un conjunto $X$ con los números pares del 2 al 10 y un conjunto $Y$ con los múltiplos de 3 hasta 12.
#
# 1. Verifique si $X$ es subconjunto de $Y$.
#
# 2. Calcule la unión e intersección de $X$ e $Y$.

# %%
# Su código aquí...

# %% [markdown]
# Doble-click __aquí__ para la solución propuesta.
# <!-- The correct answer is:
#
# X = {2, 4, 6, 8, 10}
# Y = {3, 6, 9, 12}
#
# es_subconjunto = X.issubset(Y)
# union_XY = X | Y
# interseccion_XY = X & Y
#
# print("¿X es subconjunto de Y?", es_subconjunto)
# print("Unión:", union_XY)
# print("Intersección:", interseccion_XY)
#
# -->

# %% [markdown]
# <br>
# <br>
# <p align="center"><b>
# <font color="#07a8ed">
# Hemos llegado al final de nuestro colab, a seguir codeando...
# </font>
# </p>
